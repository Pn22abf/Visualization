# %%
#Pandas :we use pandas to read csv file
# Numpy :It is widely used in scientific computing, data analysis, and machine learning applications.
#LabelEncoder :  is used to convert categorical or text data into numerical data. 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %%
# We can use funtion to show some specific columns from the dataset

def show_specific_columns(csv_path, columns):
    # Load CSV data into a pandas dataframe
    df = pd.read_csv('USA_cars_datasets.csv')
    
    # Select only the specified columns
    df = df[columns]
    
    return df

# %%
csv_path = 'USA_cars_datasets.csv'
columns = ['price', 'brand', 'year']
specific_df = show_specific_columns(csv_path, columns)
print(specific_df)
# Out:
#       price      brand  year
# 0      6300     toyota  2008
# 1      2899       ford  2011
# 2      5350      dodge  2018
# 3     25000       ford  2014
# 4     27700  chevrolet  2018
# ...     ...        ...   ...
# 2494   7800     nissan  2019
# 2495   9200     nissan  2018
# 2496   9200     nissan  2018
# 2497   9200     nissan  2018
# 2498   9200     nissan  2018
#
# [2499 rows x 3 columns]

# %%
import csv

def get_column(file_path, column_name):
    with open(file_path, 'r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        column_values = [row[column_name] for row in csv_reader]
    return column_values

# %%
column_values = get_column("USA_cars_datasets.csv", "model")
print(column_values)
# Out:
# ['cruiser', 'se', 'mpv', 'door', '1500', 'mpv', 'pk', 'door', 'malibu', 'mpv', 'coupe', 'mpv', '1500', 'wagon', 'door', 'door', 'forte', 'encore', 'mpv', 'door', 'door', 'forte', 'door', 'mpv', 'door', 'door', 'sorento', 'door', 'doors', 'chassis', 'door', 'q70', 'camaro', 'mpv', 'convertible', 'door', 'vans', '1500', 'mpv', 'pk', 'door', 'vans', '1500', 'mpv', 'srw', 'door', 'compass', 'malibu', 'mpv', 'srw', 'mpv', 'compass', 'enclave', 'mpv', '300', 'mpv', 'cherokee', 'door', 'pacifica', '300', 'door', 'cherokee', 'door', 'door', 'pacifica', 'door', 'cherokee', 'door', 'door', '300', 'door', 'compass', 'x3', 'door', '300', 'door', 'compass', 'door', 'door', '300', 'door', 'compass', 'camaro', 'door', 'door', 'door', 'compass', 'equinox', 'door', 'door', 'door', 'door', 'door', 'door', 'challenger', 'm', 'door', 'door', 'colorado', 'mpv', 'focus', 'door', 'mpv', 'focus', 'door', 'mpv', 'focus', 'malibu', 'door', 'durango', 'door', 'mpv', 'escape', '1500', 'mpv', 'charger', 'colorad
# ...

# %%
df=pd.read_csv('USA_cars_datasets.csv')

# %%
# head() funtion is used to show first 5 rows
df.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
label_encoder=LabelEncoder()
df['color']=label_encoder.fit_transform(df['color'])
label_encoder=LabelEncoder()
df['brand']=label_encoder.fit_transform(df['brand'])
label_encoder=LabelEncoder()
df['state']=label_encoder.fit_transform(df['state'])
df
# Out:
#       Unnamed: 0  price  brand    model  year   title_status   mileage  color  \
# 0              0   6300     27  cruiser  2008  clean vehicle  274117.0      2
# 1              1   2899      8       se  2011  clean vehicle  190552.0     39
# 2              2   5350      7      mpv  2018  clean vehicle   39590.0     39
# 3              3  25000      8     door  2014  clean vehicle   64146.0      4
# 4              4  27700      5     1500  2018  clean vehicle    6654.0     34
# ...          ...    ...    ...      ...   ...            ...       ...    ...
# 2494        2494   7800     24    versa  2019  clean vehicle   23609.0     34
# 2495        2495   9200     24    versa  2018  clean vehicle   34553.0     39
# 2496        2496   9200     24    versa  2018  clean vehicle   31594.0     39
# 2497        2497   9200     24    versa  2018  clean vehicle   32557.0      2
# 2498        2498   9200     24    versa  2018  clean vehicle   31371.0     39
#
# ...

# %%
# Drop is used to remove the useless coulmns
df= df.drop(['Unnamed: 0','vin'],axis='columns')
df
# Out:
#       price  brand    model  year   title_status   mileage  color        lot  \
# 0      6300     27  cruiser  2008  clean vehicle  274117.0      2  159348797
# 1      2899      8       se  2011  clean vehicle  190552.0     39  166951262
# 2      5350      7      mpv  2018  clean vehicle   39590.0     39  167655728
# 3     25000      8     door  2014  clean vehicle   64146.0      4  167753855
# 4     27700      5     1500  2018  clean vehicle    6654.0     34  167763266
# ...     ...    ...      ...   ...            ...       ...    ...        ...
# 2494   7800     24    versa  2019  clean vehicle   23609.0     34  167722715
# 2495   9200     24    versa  2018  clean vehicle   34553.0     39  167762225
# 2496   9200     24    versa  2018  clean vehicle   31594.0     39  167762226
# 2497   9200     24    versa  2018  clean vehicle   32557.0      2  167762227
# 2498   9200     24    versa  2018  clean vehicle   31371.0     39  167762228
#
#       state country      condition
# ...

# %%
df.describe()
# Out:
#               price        brand         year       mileage        color  \
# count   2499.000000  2499.000000  2499.000000  2.499000e+03  2499.000000
# mean   18767.671469     9.750300  2016.714286  5.229869e+04    25.433774
# std    12116.094936     5.886986     3.442656  5.970552e+04    17.892703
# min        0.000000     0.000000  1973.000000  0.000000e+00     0.000000
# 25%    10200.000000     7.000000  2016.000000  2.146650e+04     4.000000
# 50%    16900.000000     8.000000  2018.000000  3.536500e+04    29.000000
# 75%    25555.500000     8.000000  2019.000000  6.347250e+04    46.000000
# max    84900.000000    27.000000  2020.000000  1.017936e+06    48.000000
#
#                 lot       state
# count  2.499000e+03  2499.00000
# mean   1.676914e+08    21.64906
# std    2.038772e+05    12.59693
# min    1.593488e+08     0.00000
# 25%    1.676253e+08     9.00000
# 50%    1.677451e+08    24.00000
# 75%    1.677798e+08    32.00000
# max    1.678055e+08    43.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         2499 non-null   int64
#  1   brand         2499 non-null   int32
#  2   model         2499 non-null   object
#  3   year          2499 non-null   int64
#  4   title_status  2499 non-null   object
#  5   mileage       2499 non-null   float64
#  6   color         2499 non-null   int32
#  7   lot           2499 non-null   int64
#  8   state         2499 non-null   int32
#  9   country       2499 non-null   object
#  10  condition     2499 non-null   object
# dtypes: float64(1), int32(3), int64(3), object(4)
# memory usage: 185.6+ KB

# %%
df.isnull().sum()
# Out:
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           0
# lot             0
# state           0
# country         0
# condition       0
# dtype: int64

# %%
df.title_status.unique()
# Out:
# array(['clean vehicle', 'salvage insurance'], dtype=object)

# %%
label_encoder=LabelEncoder()
df['model']=label_encoder.fit_transform(df['model'])

label_encoder=LabelEncoder()
df['title_status']=label_encoder.fit_transform(df['title_status'])
label_encoder=LabelEncoder()
df['country']=label_encoder.fit_transform(df['country'])
label_encoder=LabelEncoder()
df['condition']=label_encoder.fit_transform(df['condition'])
df
# Out:
#       price  brand  model  year  title_status   mileage  color        lot  \
# 0      6300     27     25  2008             0  274117.0      2  159348797
# 1      2899      8     92  2011             0  190552.0     39  166951262
# 2      5350      7     75  2018             0   39590.0     39  167655728
# 3     25000      8     32  2014             0   64146.0      4  167753855
# 4     27700      5      0  2018             0    6654.0     34  167763266
# ...     ...    ...    ...   ...           ...       ...    ...        ...
# 2494   7800     24    120  2019             0   23609.0     34  167722715
# 2495   9200     24    120  2018             0   34553.0     39  167762225
# 2496   9200     24    120  2018             0   31594.0     39  167762226
# 2497   9200     24    120  2018             0   32557.0      2  167762227
# 2498   9200     24    120  2018             0   31371.0     39  167762228
#
#       state  country  condition
# 0        24        1          3
# ...

# %%
#Line graph is created by the following line of code
#.plot() is a function provided by many Python libraries, including Pandas and Matplotlib,
#that is used to create different types of plots and visualizations.
plt.figure(figsize=(18,16))
df.plot(x='year', y='price')
plt.ylabel('price')
plt.show()

# %%
plt.figure(figsize=(18,16))
df.plot(x='mileage', y='price')
plt.ylabel('Price')

plt.show()

# %%
ax = df.plot(x='year', y=['model', 'price'])
ax.set_ylabel("price ")
plt.show()

# %%
#A histogram is a graphical representation of the distribution of a dataset
#.title() is a method provided by many Python plotting libraries, including Matplotlib and Seaborn, 
#that is used to set the title of a plo
plt.hist(df['price'], color = 'blue', edgecolor = 'black',bins=10)


plt.title(' Prices Range')
plt.xlabel('Car Prices')
plt.ylabel('Number of cars')
# Out:
# Text(0, 0.5, 'Number of cars')

# %%
plt.hist(df['model'], color = 'Red', edgecolor = 'black',bins=10)


plt.title('Mileage Consumption')
plt.xlabel('model')
plt.ylabel('mileage')
# Out:
# Text(0, 0.5, 'mileage')

# %%
#sns.scatterplot() is a method provided by the Python visualization library Seaborn that is used to create a scatter plot.
plt.figure(figsize=(12,6))
sns.scatterplot(x=df['price'], y=df['mileage']);

# %%
#Scatter plots are also useful for identifying outliers, clusters, and other interesting features in the data. 
plt.figure(figsize=(12,6))
sns.scatterplot(x=df['brand'], y=df['year']);
